# %%
dataframe1 = spark.read.csv("/Volumes/workspace/dwh_schema/filestorevolume/SalesData.csv", header = "true")

# %%
dataframe1.createTempView("vwSalesData")

# %%
# %sql
select * from vwSalesData
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select Country, Company, Month, sum(CAST(REPLACE(Sale2018, ',', '') AS DOUBLE)) as Sale2018_sum
from vwSalesData
where Month = "April" or Month = "May"
group by Country, Company, Month
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
dataframedest = spark.sql(""" 
                          select Country, Company, Month, sum(CAST(REPLACE(Sale2018, ',', '') AS DOUBLE)) as Sale2018_sum
from vwSalesData
where Month = "April" or Month = "May"
group by Country, Company, Month
                          """)
display(dataframedest)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
dataframedest.write.format("delta").saveAsTable("tblAggrSales")

# %%
# %sql
select * from tblAggrSales
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
